# %%
import sys

import keras
import pandas as pd
import sklearn as sk
import tensorflow as tf

print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
# Out:
# Using TensorFlow backend.
# Tensor Flow Version: 1.12.0
# Keras Version: 2.2.4
#
# Python 3.6.8 |Anaconda, Inc.| (default, Dec 30 2018, 18:50:55) [MSC v.1915 64 bit (AMD64)]
# Pandas 0.23.4
# Scikit-Learn 0.20.2

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
# %matplotlib inline

# %%
DATADIR="C:/Users/elmor/My project/Garbge Collection - Kaggle/garbage-classification/Garbage classification/Garbage classification"
#img=cv2.imread("C:\\Users\\elmor\\My project\\Garbge Collection - Kaggle\\garbage-classification\\Garbage classification\\Garbage classification\\paper\\paper9.jpg")
#img=cv2.imread("C:\\Users\\elmor\\My project\\Garbge Collection - Kaggle\\garbage-classification\\Garbage classification\\Garbage classification\\paper\\paper9.jpg",0)
CATEGORIES=["glass","paper","cardboard","plastic","metal","trash"]
#ii
for category in CATEGORIES:
    mypath=os.path.join(DATADIR,category) # get to the directory of images 
    for i in os.listdir(path=mypath):     # listing all items in the dir
        img_array=cv2.imread(os.path.join(mypath,i),cv2.IMREAD_GRAYSCALE) # cv2.COLOR_BGR2RGB) # by default it reads images into array/matrix
        plt.imshow(img_array,cmap='gray')
        #ii+=ii
        #print(i)
        #if ii==3:
        break
    break
# Out:
# cardboard1.jpg

# %%
print(img_array)
# Out:
# [[208 208 209 ... 180 182 183]
#  [209 210 211 ... 181 182 182]
#  [211 212 212 ... 182 181 181]
#  ...
#  [155 156 158 ...  95  95  95]
#  [155 155 155 ...  94  95  95]
#  [157 155 153 ...  94  95  95]]

# %%
#plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
#plt.imshow(img)
#plt.axis('off')
#plt.show()

# %%
img_array.shape
# Out:
# (384, 512)

# %%
## resize
IMG_SIZE=150
new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))

# %%
plt.imshow(new_array,"gray")

# %%
# Create Dataframe --> not needed
# dframe=pd.read_csv("C:/Users/elmor/My project/Garbge Collection - Kaggle/garbage-classification/one-indexed-files3.csv",",")
# dframe_shape=list(dframe.shape)

# Create the Trainng Set.
# 1 Load the training list as a table

dframe_train=pd.read_csv("C:/Users/elmor/My project/Garbge Collection - Kaggle/garbage-classification/one-indexed-files-notrash_train_mod.csv",",")
dframe_shape_train=list(dframe_train.shape)

# %%
dframe_shape_train
# Out:
# [1768, 2]

# %%
dframe_train.head(5)
# Out:
#               Image  Class
# 0  cardboard202.jpg      3
# 1      paper472.jpg      2
# 2      paper522.jpg      2
# 3      glass189.jpg      1
# 4      glass325.jpg      1

# %%
# DATADIR="C:/Users/elmor/My project/Garbge Collection - Kaggle/garbage-classification/Garbage classification/Garbage classification"
# #img=cv2.imread("C:\\Users\\elmor\\My project\\Garbge Collection - Kaggle\\garbage-classification\\Garbage classification\\Garbage classification\\paper\\paper9.jpg")
# #img=cv2.imread("C:\\Users\\elmor\\My project\\Garbge Collection - Kaggle\\garbage-classification\\Garbage classification\\Garbage classification\\paper\\paper9.jpg",0)
# CATEGORIES=["glass","paper","cardboard","plastic","metal","trash"]
# #ii
# track=[]
# image_array=[]
# for category in CATEGORIES:
#     mypath=os.path.join(DATADIR,category) # get to the directory of images 
    
#     for image in os.listdir(path=mypath):     # listing all items in the dir
#         #for im_index in range(dframe_shape[0]):
#         #    if image==dframe.Image[im_index]:
#         image_array.append([cv2.imread(os.path.join(mypath,image),cv2.IMREAD_GRAYSCALE),image]) #dframe.Class[im_index]]) # cv2.COLOR_BGR2RGB) # by default it reads images into array/matrix
#         #plt.imshow(img_array,cmap='gray')
#         track.append(image)

# %%
DATADIR="C:/Users/elmor/My project/Garbge Collection - Kaggle/garbage-classification/Garbage classification/Garbage classification"
#img=cv2.imread("C:\\Users\\elmor\\My project\\Garbge Collection - Kaggle\\garbage-classification\\Garbage classification\\Garbage classification\\paper\\paper9.jpg")
#img=cv2.imread("C:\\Users\\elmor\\My project\\Garbge Collection - Kaggle\\garbage-classification\\Garbage classification\\Garbage classification\\paper\\paper9.jpg",0)
CATEGORIES=["glass","paper","cardboard","plastic","metal","trash"]
#ii
image_train_label=[]
image_train_array=[]

for loop1 in range(dframe_shape_train[0]):
    for category in CATEGORIES:
        mypath=os.path.join(DATADIR,category) # get to the directory of images 
    
        for image in os.listdir(path=mypath):     # listing all items in the dir
        #for im_index in range(dframe_shape[0]):
        #    if image==dframe.Image[im_index]:
            if dframe_train.Image[loop1]==image:
                image_train_array.append(cv2.imread(os.path.join(mypath,image),cv2.IMREAD_GRAYSCALE)) #dframe.Class[im_index]]) # cv2.COLOR_BGR2RGB) # by default it reads images into array/matrix
        #plt.imshow(img_array,cmap='gray')
                image_train_label.append(dframe_train.Class[loop1])

# %%
len(image_train_array)
# Out:
# 1768

# %%
image_train_array[1][383][511]
# Out:
# 218

# %%
image_train_label[7]
# Out:
# 6

# %%
#type(image_array)

# %%
#one_index=open("C:/Users/elmor/My project/Garbge Collection - Kaggle/garbage-classification/one-indexed-files3.csv")
#text_line=one_index.read().split(",").split("\n")
#text_line=text_line.split("\t")
#or ii in track:

# %%
# Create the test set

dframe_test=pd.read_csv("C:/Users/elmor/My project/Garbge Collection - Kaggle/garbage-classification/one-indexed-files-notrash_test_mod.csv",",")
dframe_shape_test=list(dframe_test.shape)

# %%
dframe_test.head(5)
# Out:
#              Image  Class
# 0      paper70.jpg      2
# 1     paper380.jpg      2
# 2  cardboard31.jpg      3
# 3      glass12.jpg      1
# 4     paper169.jpg      2

# %%
image_test_label=[]
image_test_array=[]

for loop1 in range(dframe_shape_test[0]):
    for category in CATEGORIES:
        mypath=os.path.join(DATADIR,category) # get to the directory of images 
    
        for image in os.listdir(path=mypath):     # listing all items in the dir
        #for im_index in range(dframe_shape[0]):
        #    if image==dframe.Image[im_index]:
            if dframe_test.Image[loop1]==image:
                image_test_array.append(cv2.imread(os.path.join(mypath,image),cv2.IMREAD_GRAYSCALE)) #dframe.Class[im_index]]) # cv2.COLOR_BGR2RGB) # by default it reads images into array/matrix
        #plt.imshow(img_array,cmap='gray')
                image_test_label.append(dframe_test.Class[loop1])

# %%
# Create the testing  Set -- Data and Labels
# image_array_train_data=[]
# image_array_train_labels=[]

# for im_index in range (dframe_shape_train[0]):
#     for other_index in range(dframe_shape[0]):
#         if dframe_train.Image[im_index]==image_array[other_index][1]:
#             dummy=image_array[other_index][0] #.flatten()
#             image_array_train_data.append(dummy) #,dframe_train.Class[im_inde
#             image_array_train_labels.append(dframe_train.Class[im_index])

# %%
# Create the Dtaframe
# dframe=pd.read_csv("C:/Users/elmor/My project/Garbge Collection - Kaggle/garbage-classification/one-indexed-files3.csv",",")
image_test_label[5]
# Out:
# 3

# %%
#dframe.head()

# %%
# convert the trinin set list to a Numpy Array for Keras
# the image_array_train is a list

imageX_train=np.array(image_train_array)
imageY_train=np.array(image_train_label)

# %%
imageY_test=np.array(image_test_label)
imageX_test=np.array(image_test_array)

# %%
#xx[0]
#dframe.Class[3]
#imageX_train_red.shape #)#im_array_train.shape
type(imageX_test)
# Out:
# numpy.ndarray

# %%
#imageY_train_red.shape
# Out:
# (10,)

# %%
#type(im_array_train)

# %%
# # Create the Testing  Set.

# dframe_test=pd.read_csv("C:/Users/elmor/My project/Garbge Collection - Kaggle/garbage-classification/one-indexed-files-notrash_test_mod.csv",",")
# dframe_shape_test=list(dframe_test.shape)

# # create the validation Set
# # dframe_val=pd.read_csv("C:/Users/elmor/My project/Garbge Collection - Kaggle/garbage-classification/one-indexed-files-notrash_val_mod.csv",",")
# # dframe_shape_val=list(dframe_val.shape)

# %%
#dframe_test.shape

# %%
# Create the test set

# image_array_test_data=[]
# image_array_test_labels=[]

# for im_index in range (dframe_shape_test[0]):
#     for other_index in range(dframe_shape[0]):
#         if dframe_test.Image[im_index]==image_array[other_index][1]:
#             #image_array_test.append([image_array[other_index][0],dframe_test.Class[im_index]]) #,dframe_train.Class[im_inde
#             dummy=image_array[other_index][0].flatten()
#             image_array_test_data.append(dummy) #,dframe_train.Class[im_inde
#             image_array_test_labels.append(dframe_test.Class[im_index])


# #Create the validation set
# """

# image_array_val=[]
# for im_index in range (dframe_shape_train[0]):
#     for other_index in range(dframe_shape[0]):
#         if dframe_train.Image[im_index]==image_array[other_index][1]:
#             image_array_train.append([image_array[other_index][0],dframe_train.Class[im_index]]) #,dframe_train.Class[im_inde
# """

# %%
#len(image_array_test_data)

# %%
#|len(image_array_test_labels)

# %%
# DATADIR="C:/Users/elmor/My project/Garbge Collection - Kaggle/garbage-classification/Garbage classification/Garbage classification"
# #img=cv2.imread("C:\\Users\\elmor\\My project\\Garbge Collection - Kaggle\\garbage-classification\\Garbage classification\\Garbage classification\\paper\\paper9.jpg")
# #img=cv2.imread("C:\\Users\\elmor\\My project\\Garbge Collection - Kaggle\\garbage-classification\\Garbage classification\\Garbage classification\\paper\\paper9.jpg",0)
# CATEGORIES=["glass","paper","cardboard","plastic","metal","trash"]
# #ii
# track_train=[]
# image_array_train=[]
# for category in CATEGORIES:
#     mypath=os.path.join(DATADIR,category) # get to the directory of images 
    
#     for image in os.listdir(path=mypath):     # listing all items in the dir
#         for im_index in range(dframe_shape_train[0]):
#             if image==dframe_train.Image[im_index]:
#                 image_array_train.append(image_array[][0][cv2.imread(os.path.join(mypath,image),cv2.IMREAD_GRAYSCALE),dframe_train.Class[im_index]]) # cv2.COLOR_BGR2RGB) # by default it reads images into array/matrix
#         #plt.imshow(img_array,cmap='gray')
#         track_train.append(image)

# %%
x_train = imageX_train/255 #tf.keras.utils.normalize(imageX_train, axis=1)  # scales data between 0 and 1
#

# %%
print(x_train.max())
print(x_train.min())
print(x_train.shape)
x_train[1]
# Out:
# 1.0
# 0.0
# (1768, 384, 512)
# array([[0.90196078, 0.90196078, 0.90196078, ..., 0.83137255, 0.83137255,
#         0.83137255],
#        [0.90196078, 0.90196078, 0.90196078, ..., 0.83137255, 0.83137255,
#         0.83137255],
#        [0.90196078, 0.90196078, 0.90196078, ..., 0.83137255, 0.83137255,
#         0.83137255],
#        ...,
#        [0.90588235, 0.90588235, 0.90588235, ..., 0.85490196, 0.85490196,
#         0.85490196],
#        [0.90588235, 0.90588235, 0.90588235, ..., 0.85490196, 0.85490196,
#         0.85490196],
#        [0.90588235, 0.90588235, 0.90588235, ..., 0.85490196, 0.85490196,
#         0.85490196]])

# %%
x_test = imageX_test/255 #tf.keras.utils.normalize(imageX_test, axis=1)  # scales data between 0 and 1

# %%
print(x_test.max())
print(x_test.min())
print(x_test.shape)
# Out:
# 1.0
# 0.0
# (431, 384, 512)

# %%
model = tf.keras.models.Sequential()  # a basic feed-forward model
model.add(tf.keras.layers.Flatten())  # takes our 28x28 and makes it 1x784

# %%
y_train=imageY_train

# %%
y_test=imageY_test

# %%
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))  # a simple fully-connected layer, 128 units, relu activation
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))  # a simple fully-connected layer, 128 units, relu activation
model.add(tf.keras.layers.Dense(7, activation=tf.nn.softmax))  # our output layer. 10 units for 10 classes. Softmax for probability distribution

model.compile(optimizer='adam',  # Good default optimizer to start with
              loss='sparse_categorical_crossentropy',  # how will we calculate our "error." Neural network aims to minimize loss.
              metrics=['accuracy'])  # what to track

model.fit(x_train, y_train, epochs=3)  # train the model

val_loss, val_acc = model.evaluate(x_test, y_test)  # evaluate the out of sample data with model
print(val_loss)  # model's loss (error)
print(val_acc)  # model's accuracy
# Out:
# Epoch 1/3
# 1768/1768 [==============================] - 34s 19ms/step - loss: 12.7643 - acc: 0.1968
# Epoch 2/3
# 1768/1768 [==============================] - 32s 18ms/step - loss: 12.9546 - acc: 0.1963
# Epoch 3/3
# ...
# 431/431 [==============================] - 2s 5ms/step
# 13.350719392161357
# 0.17169373574085411

# %%
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_4 (Flatten)          multiple                  0
# _________________________________________________________________
# dense_33 (Dense)             multiple                  25165952
# _________________________________________________________________
# dense_34 (Dense)             multiple                  16512
# _________________________________________________________________
# dense_35 (Dense)             multiple                  903
# ...
# Total params: 25,183,367
# Trainable params: 25,183,367
# Non-trainable params: 0
# _________________________________________________________________
# None
